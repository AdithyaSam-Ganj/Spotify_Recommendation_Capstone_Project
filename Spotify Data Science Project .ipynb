# %%
#Primary Imports 

# Data Handling 
import numpy as np 
import pandas as pd

#Visualisation 
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns 


#Ignore Warnings
import warnings
warnings.filterwarnings('ignore')



from yellowbrick.target import FeatureCorrelation

# %%
# Loading all the data sets 
#df_artist = pd.read_csv('artists.csv')
#df_tracks = pd.read_csv('tracks.csv')

#The other project Data 
df_artist = pd.read_csv('data_by_artist_p.csv')
df_gener = pd.read_csv('data_by_genres_p.csv')
df_year = pd.read_csv('data_by_year_p.csv')
df = pd.read_csv('data_p.csv')
df_w_gener = pd.read_csv('data_w_genres_p.csv')

# %%
df.head()
# Out:
#    valence  year  acousticness  \
# 0   0.0594  1921         0.982
# 1   0.9630  1921         0.732
# 2   0.0394  1921         0.961
# 3   0.1650  1921         0.967
# 4   0.2530  1921         0.957
#
#                                              artists  danceability  \
# 0  ['Sergei Rachmaninoff', 'James Levine', 'Berli...         0.279
# 1                                     ['Dennis Day']         0.819
# 2  ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...         0.328
# 3                                   ['Frank Parker']         0.275
# 4                                     ['Phil Regan']         0.418
#
#    duration_ms  energy  explicit                      id  instrumentalness  \
# 0       831667   0.211         0  4BJqT0PrAfrxzMOxytFOIz          0.878000
# 1       180533   0.341         0  7xPhfUan2yNtyFG0cUWkt8          0.000000
# 2       500062   0.166         0  1o6I8BglA6ylDMrIELygv1          0.913000
# 3       210000   0.309         0  3ftBPsC5vPBKxYSee08FDH          0.000028
# 4       166693   0.193         0  4d6HGyGT8e121BsdKmw9v6          0.000002
#
#    key  liveness  loudness  mode  \
# 0   10     0.665   -20.096     1
# 1    7     0.160   -12.441     1
# 2    3     0.101   -14.850     1
# 3    5     0.381    -9.316     1
# 4    3     0.229   -10.096     1
#
#                                                 name  popularity release_date  \
# 0  Piano Concerto No. 3 in D Minor, Op. 30: III. ...           4         1921
# 1                            Clancy Lowered the Boom           5         1921
# 2                                          Gati Bali           5         1921
# 3                                          Danny Boy           3         1921
# 4                        When Irish Eyes Are Smiling           2         1921
#
#    speechiness    tempo
# 0       0.0366   80.954
# 1       0.4150   60.936
# 2       0.0339  110.339
# 3       0.0354  100.109
# 4       0.0380  101.665

# %%
df_artist.head()
# Out:
#    mode  count  acousticness  \
# 0     1      9      0.590111
# 1     1     26      0.862538
# 2     1      7      0.856571
# 3     1     27      0.884926
# 4     1      7      0.510714
#
#                                              artists  danceability  \
# 0                   "Cats" 1981 Original London Cast      0.467222
# 1                          "Cats" 1983 Broadway Cast      0.441731
# 2        "Fiddler On The Roof” Motion Picture Chorus      0.348286
# 3     "Fiddler On The Roof” Motion Picture Orchestra      0.425074
# 4  "Joseph And The Amazing Technicolor Dreamcoat"...      0.467143
#
#      duration_ms    energy  instrumentalness  liveness   loudness  \
# 0  250318.555556  0.394003          0.011400  0.290833 -14.448000
# 1  287280.000000  0.406808          0.081158  0.315215 -10.690000
# 2  328920.000000  0.286571          0.024593  0.325786 -15.230714
# 3  262890.962963  0.245770          0.073587  0.275481 -15.639370
# 4  270436.142857  0.488286          0.009400  0.195000 -10.236714
#
#    speechiness       tempo   valence  popularity  key
# 0     0.210389  117.518111  0.389500   38.333333    5
# 1     0.176212  103.044154  0.268865   30.576923    5
# 2     0.118514   77.375857  0.354857   34.857143    0
# 3     0.123200   88.667630  0.372030   34.851852    0
# 4     0.098543  122.835857  0.482286   43.000000    5

# %%
df_gener.head()
# Out:
#    mode                  genres  acousticness  danceability   duration_ms  \
# 0     1  21st century classical      0.979333      0.162883  1.602977e+05
# 1     1                   432hz      0.494780      0.299333  1.048887e+06
# 2     1                   8-bit      0.762000      0.712000  1.151770e+05
# 3     1                      []      0.651417      0.529093  2.328809e+05
# 4     1              a cappella      0.676557      0.538961  1.906285e+05
#
#      energy  instrumentalness  liveness   loudness  speechiness       tempo  \
# 0  0.071317          0.606834  0.361600 -31.514333     0.040567   75.336500
# 1  0.450678          0.477762  0.131000 -16.854000     0.076817  120.285667
# 2  0.818000          0.876000  0.126000  -9.180000     0.047000  133.444000
# 3  0.419146          0.205309  0.218696 -12.288965     0.107872  112.857352
# 4  0.316434          0.003003  0.172254 -12.479387     0.082851  112.110362
#
#     valence  popularity  key
# 0  0.103783   27.833333    6
# 1  0.221750   52.500000    5
# 2  0.975000   48.000000    7
# 3  0.513604   20.859882    7
# 4  0.448249   45.820071    7

# %%
df_year.head()
# Out:
#    mode  year  acousticness  danceability    duration_ms    energy  \
# 0     1  1921      0.886896      0.418597  260537.166667  0.231815
# 1     1  1922      0.938592      0.482042  165469.746479  0.237815
# 2     1  1923      0.957247      0.577341  177942.362162  0.262406
# 3     1  1924      0.940200      0.549894  191046.707627  0.344347
# 4     1  1925      0.962607      0.573863  184986.924460  0.278594
#
#    instrumentalness  liveness   loudness  speechiness       tempo   valence  \
# 0          0.344878  0.205710 -17.048667     0.073662  101.531493  0.379327
# 1          0.434195  0.240720 -19.275282     0.116655  100.884521  0.535549
# 2          0.371733  0.227462 -14.129211     0.093949  114.010730  0.625492
# 3          0.581701  0.235219 -14.231343     0.092089  120.689572  0.663725
# 4          0.418297  0.237668 -14.146414     0.111918  115.521921  0.621929
#
#    popularity  key
# 0    0.653333    2
# 1    0.140845   10
# 2    5.389189    0
# 3    0.661017   10
# 4    2.604317    5

# %%
df_w_gener.head()
# Out:
#            genres                                            artists  \
# 0  ['show tunes']                   "Cats" 1981 Original London Cast
# 1              []                          "Cats" 1983 Broadway Cast
# 2              []        "Fiddler On The Roof” Motion Picture Chorus
# 3              []     "Fiddler On The Roof” Motion Picture Orchestra
# 4              []  "Joseph And The Amazing Technicolor Dreamcoat"...
#
#    acousticness  danceability    duration_ms    energy  instrumentalness  \
# 0      0.590111      0.467222  250318.555556  0.394003          0.011400
# 1      0.862538      0.441731  287280.000000  0.406808          0.081158
# 2      0.856571      0.348286  328920.000000  0.286571          0.024593
# 3      0.884926      0.425074  262890.962963  0.245770          0.073587
# 4      0.510714      0.467143  270436.142857  0.488286          0.009400
#
#    liveness   loudness  speechiness       tempo   valence  popularity  key  \
# 0  0.290833 -14.448000     0.210389  117.518111  0.389500   38.333333    5
# 1  0.315215 -10.690000     0.176212  103.044154  0.268865   30.576923    5
# 2  0.325786 -15.230714     0.118514   77.375857  0.354857   34.857143    0
# 3  0.275481 -15.639370     0.123200   88.667630  0.372030   34.851852    0
# 4  0.195000 -10.236714     0.098543  122.835857  0.482286   43.000000    5
#
#    mode  count
# 0     1      9
# 1     1     26
# 2     1      7
# 3     1     27
# 4     1      7

# %%
df.columns
# Out:
# Index(['valence', 'year', 'acousticness', 'artists', 'danceability',
#        'duration_ms', 'energy', 'explicit', 'id', 'instrumentalness', 'key',
#        'liveness', 'loudness', 'mode', 'name', 'popularity', 'release_date',
#        'speechiness', 'tempo'],
#       dtype='object')

# %%
df_artist.columns
# Out:
# Index(['mode', 'count', 'acousticness', 'artists', 'danceability',
#        'duration_ms', 'energy', 'instrumentalness', 'liveness', 'loudness',
#        'speechiness', 'tempo', 'valence', 'popularity', 'key'],
#       dtype='object')

# %%
df_gener.columns
# Out:
# Index(['mode', 'genres', 'acousticness', 'danceability', 'duration_ms',
#        'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness',
#        'tempo', 'valence', 'popularity', 'key'],
#       dtype='object')

# %%
df_artist.columns
# Out:
# Index(['mode', 'count', 'acousticness', 'artists', 'danceability',
#        'duration_ms', 'energy', 'instrumentalness', 'liveness', 'loudness',
#        'speechiness', 'tempo', 'valence', 'popularity', 'key'],
#       dtype='object')

# %%
df_gener.columns
# Out:
# Index(['mode', 'genres', 'acousticness', 'danceability', 'duration_ms',
#        'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness',
#        'tempo', 'valence', 'popularity', 'key'],
#       dtype='object')

# %%
df_year.columns
# Out:
# Index(['mode', 'year', 'acousticness', 'danceability', 'duration_ms', 'energy',
#        'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo',
#        'valence', 'popularity', 'key'],
#       dtype='object')

# %%
df_w_gener.columns
# Out:
# Index(['genres', 'artists', 'acousticness', 'danceability', 'duration_ms',
#        'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness',
#        'tempo', 'valence', 'popularity', 'key', 'mode', 'count'],
#       dtype='object')

# %% [markdown]
# # EDA

# %%
# Tried to group by artists and look at data. but it is very confusing because of the way it is arranged. 
# trying to drop  [ ] '
df['artists']=df['artists'].str.replace('[','')
df['artists']=df['artists'].str.replace(']','')
df['artists']=df['artists'].str.replace("'","")
df['artists'].head()
# Out:
# 0    Sergei Rachmaninoff, James Levine, Berliner Ph...
# 1                                           Dennis Day
# 2    KHP Kridhamardawa Karaton Ngayogyakarta Hadini...
# 3                                         Frank Parker
# 4                                           Phil Regan
# Name: artists, dtype: object

# %% [markdown]
# ### Checking for Duplicates

# %%
# df has no duplicates but it has a unique ID for every entry. 
#If we drop the unique id and then lookfor the duplicates we might find some 

dfn = df.drop(['id'], axis = 1)
dfn.shape
# Out:
# (170653, 18)

# %%
dfn.duplicated().sum()
# Out:
# 543

# %%
dfn = df.drop(['id'], axis = 1)
dfn = dfn.drop_duplicates()
dfn.shape
# Out:
# (170110, 18)

# %%
df.columns
# Out:
# Index(['valence', 'year', 'acousticness', 'artists', 'danceability',
#        'duration_ms', 'energy', 'explicit', 'id', 'instrumentalness', 'key',
#        'liveness', 'loudness', 'mode', 'name', 'popularity', 'release_date',
#        'speechiness', 'tempo'],
#       dtype='object')

# %% [markdown]
# ### Time to listen to all songs

# %%
df.duration_ms.sum()/(24*365*60*60000)
# Out:
# 1.249747021182141

# %%
#Visualisation of Variability for each column in the dataframe

plt.rcParams.update({'font.size': 22})


fig,ax = plt.subplots(4,4,figsize=(20,20))

sns.distplot(df['valence'],ax=ax[0,0])
sns.distplot(df['year'],ax=ax[0,1])
sns.distplot(df['acousticness'],ax=ax[0,2])
sns.distplot(df['danceability'],ax=ax[0,3])
#sns.distplot(df['duration_min'],ax=ax[1,1])
sns.distplot(df['energy'],ax=ax[1,0])
sns.distplot(df['key'],ax=ax[1,1])
sns.distplot(df['liveness'],ax=ax[1,2])
sns.distplot(df['loudness'],ax=ax[1,3])
sns.distplot(df['popularity'],ax=ax[2,0])
sns.distplot(df['speechiness'],ax=ax[2,1])
sns.distplot(df['tempo'],ax=ax[2,2])
sns.distplot(df['mode'],ax=ax[2,3])
sns.distplot(df['duration_ms'],ax=ax[3,0])
# Out:
# <AxesSubplot:xlabel='duration_ms', ylabel='Density'>

# %%
plt.figure(figsize=(20,10))
sns.set(style="whitegrid")
corr = df.corr()
sns.heatmap(corr,annot=True,cmap='BrBG_r',annot_kws={"fontsize":12})
# Out:
# <AxesSubplot:>

# %%
beatles = df[df['artists']=='The Beatles']
beatles.groupby('name')

# %%
pd.pivot_table(df, index= ['artists','name'], aggfunc = 'count')#), values = 'name')#.sort_values('average_salary' , ascending = False)
# Out:
#                                              acousticness  danceability  \
# artists                name
# "Adolescents Orquesta" Anhelo                           1             1
#                        Aquel Lugar                      1             1
#                        Arrepentida                      1             1
#                        Me Tengo Que Ir                  1             1
#                        Persona Ideal                    1             1
# ...                                                   ...           ...
# 黃國隆                    思想起                              1             1
#                        藝旦調                              1             1
# 黃國隆, 王秋玉               草螟弄雞公                            1             1
# 黑豹                     DON'T BREAK MY HEART             1             1
# 조정현                    그아픔까지사랑한거야                       1             1
#
#                                              duration_ms  energy  explicit  \
# artists                name
# "Adolescents Orquesta" Anhelo                          1       1         1
#                        Aquel Lugar                     1       1         1
#                        Arrepentida                     1       1         1
#                        Me Tengo Que Ir                 1       1         1
#                        Persona Ideal                   1       1         1
# ...                                                  ...     ...       ...
# 黃國隆                    思想起                             1       1         1
#                        藝旦調                             1       1         1
# 黃國隆, 王秋玉               草螟弄雞公                           1       1         1
# 黑豹                     DON'T BREAK MY HEART            1       1         1
# 조정현                    그아픔까지사랑한거야                      1       1         1
#
#                                              id  instrumentalness  key  \
# artists                name
# "Adolescents Orquesta" Anhelo                 1                 1    1
#                        Aquel Lugar            1                 1    1
#                        Arrepentida            1                 1    1
#                        Me Tengo Que Ir        1                 1    1
#                        Persona Ideal          1                 1    1
# ...                                          ..               ...  ...
# 黃國隆                    思想起                    1                 1    1
#                        藝旦調                    1                 1    1
# 黃國隆, 王秋玉               草螟弄雞公                  1                 1    1
# 黑豹                     DON'T BREAK MY HEART   1                 1    1
# 조정현                    그아픔까지사랑한거야             1                 1    1
#
#                                              liveness  loudness  mode  \
# artists                name
# "Adolescents Orquesta" Anhelo                       1         1     1
#                        Aquel Lugar                  1         1     1
#                        Arrepentida                  1         1     1
#                        Me Tengo Que Ir              1         1     1
#                        Persona Ideal                1         1     1
# ...                                               ...       ...   ...
# 黃國隆                    思想起                          1         1     1
#                        藝旦調                          1         1     1
# 黃國隆, 王秋玉               草螟弄雞公                        1         1     1
# 黑豹                     DON'T BREAK MY HEART         1         1     1
# 조정현                    그아픔까지사랑한거야                   1         1     1
#
#                                              popularity  release_date  \
# artists                name
# "Adolescents Orquesta" Anhelo                         1             1
#                        Aquel Lugar                    1             1
#                        Arrepentida                    1             1
#                        Me Tengo Que Ir                1             1
#                        Persona Ideal                  1             1
# ...                                                 ...           ...
# 黃國隆                    思想起                            1             1
#                        藝旦調                            1             1
# 黃國隆, 王秋玉               草螟弄雞公                          1             1
# 黑豹                     DON'T BREAK MY HEART           1             1
# 조정현                    그아픔까지사랑한거야                     1             1
#
#                                              speechiness  tempo  valence  year
# artists                name
# "Adolescents Orquesta" Anhelo                          1      1        1     1
#                        Aquel Lugar                     1      1        1     1
#                        Arrepentida                     1      1        1     1
#                        Me Tengo Que Ir                 1      1        1     1
#                        Persona Ideal                   1      1        1     1
# ...                                                  ...    ...      ...   ...
# 黃國隆                    思想起                             1      1        1     1
#                        藝旦調                             1      1        1     1
# 黃國隆, 王秋玉               草螟弄雞公                           1      1        1     1
# 黑豹                     DON'T BREAK MY HEART            1      1        1     1
# 조정현                    그아픔까지사랑한거야                      1      1        1     1
#
# [157685 rows x 17 columns]

# %%
pd.pivot_table(beatles, index= ['artists','name'])#, aggfunc = 'count')#), values = 'name')#.sort_values('average_salary' , ascending = False)
# Out:
#                                                                 acousticness  \
# artists     name
# The Beatles A Day In The Life                                          0.257
#             A Day In The Life - First Mono Mix                         0.324
#             A Day In The Life - Hummed Last Chord / Takes 8...         0.869
#             A Day In The Life - Orchestra Overdub                      0.819
#             A Day In The Life - Remastered 2009                        0.290
# ...                                                                      ...
#             You Really Got A Hold On Me - Remastered 2009              0.525
#             You Won't See Me - Remastered 2009                         0.136
#             You're Going To Lose That Girl - Remastered 2009           0.346
#             You've Got To Hide Your Love Away - Remastered ...         0.201
#             Your Mother Should Know - Remastered 2009                  0.784
#
#                                                                 danceability  \
# artists     name
# The Beatles A Day In The Life                                         0.3320
#             A Day In The Life - First Mono Mix                        0.4780
#             A Day In The Life - Hummed Last Chord / Takes 8...        0.4230
#             A Day In The Life - Orchestra Overdub                     0.2430
#             A Day In The Life - Remastered 2009                       0.3640
# ...                                                                      ...
#             You Really Got A Hold On Me - Remastered 2009             0.3730
#             You Won't See Me - Remastered 2009                        0.4880
#             You're Going To Lose That Girl - Remastered 2009          0.5330
#             You've Got To Hide Your Love Away - Remastered ...        0.3965
#             Your Mother Should Know - Remastered 2009                 0.6980
#
#                                                                 duration_ms  \
# artists     name
# The Beatles A Day In The Life                                      323027.0
#             A Day In The Life - First Mono Mix                     283107.0
#             A Day In The Life - Hummed Last Chord / Takes 8...     114560.0
#             A Day In The Life - Orchestra Overdub                   55787.0
#             A Day In The Life - Remastered 2009                    337413.0
# ...                                                                     ...
#             You Really Got A Hold On Me - Remastered 2009          181347.0
#             You Won't See Me - Remastered 2009                     199960.0
#             You're Going To Lose That Girl - Remastered 2009       138667.0
#             You've Got To Hide Your Love Away - Remastered ...     130213.5
#             Your Mother Should Know - Remastered 2009              148413.0
#
#                                                                 energy  \
# artists     name
# The Beatles A Day In The Life                                    0.380
#             A Day In The Life - First Mono Mix                   0.330
#             A Day In The Life - Hummed Last Chord / Takes 8...   0.226
#             A Day In The Life - Orchestra Overdub                0.570
#             A Day In The Life - Remastered 2009                  0.457
# ...                                                                ...
#             You Really Got A Hold On Me - Remastered 2009        0.388
#             You Won't See Me - Remastered 2009                   0.539
#             You're Going To Lose That Girl - Remastered 2009     0.660
#             You've Got To Hide Your Love Away - Remastered ...   0.377
#             Your Mother Should Know - Remastered 2009            0.293
#
#                                                                 explicit  \
# artists     name
# The Beatles A Day In The Life                                          0
#             A Day In The Life - First Mono Mix                         0
#             A Day In The Life - Hummed Last Chord / Takes 8...         0
#             A Day In The Life - Orchestra Overdub                      0
#             A Day In The Life - Remastered 2009                        0
# ...                                                                  ...
#             You Really Got A Hold On Me - Remastered 2009              0
#             You Won't See Me - Remastered 2009                         0
#             You're Going To Lose That Girl - Remastered 2009           0
#             You've Got To Hide Your Love Away - Remastered ...         0
#             Your Mother Should Know - Remastered 2009                  0
#
#                                                                 instrumentalness  \
# artists     name
# The Beatles A Day In The Life                                           0.000474
#             A Day In The Life - First Mono Mix                          0.001470
#             A Day In The Life - Hummed Last Chord / Takes 8...          0.000000
#             A Day In The Life - Orchestra Overdub                       0.659000
#             A Day In The Life - Remastered 2009                         0.000106
# ...                                                                          ...
#             You Really Got A Hold On Me - Remastered 2009               0.000000
#             You Won't See Me - Remastered 2009                          0.000000
#             You're Going To Lose That Girl - Remastered 2009            0.000000
#             You've Got To Hide Your Love Away - Remastered ...          0.000000
#             Your Mother Should Know - Remastered 2009                   0.010600
#
#                                                                 key  liveness  \
# artists     name
# The Beatles A Day In The Life                                   4.0    0.2550
#             A Day In The Life - First Mono Mix                  4.0    0.4660
#             A Day In The Life - Hummed Last Chord / Takes 8...  9.0    0.3580
#             A Day In The Life - Orchestra Overdub               7.0    0.2970
#             A Day In The Life - Remastered 2009                 4.0    0.9220
# ...                                                             ...       ...
#             You Really Got A Hold On Me - Remastered 2009       9.0    0.2670
#             You Won't See Me - Remastered 2009                  9.0    0.0538
#             You're Going To Lose That Girl - Remastered 2009    4.0    0.2600
#             You've Got To Hide Your Love Away - Remastered ...  7.0    0.0988
#             Your Mother Should Know - Remastered 2009           0.0    0.0936
#
#                                                                 loudness  \
# artists     name
# The Beatles A Day In The Life                                   -14.6010
#             A Day In The Life - First Mono Mix                  -13.2980
#             A Day In The Life - Hummed Last Chord / Takes 8...  -23.1090
#             A Day In The Life - Orchestra Overdub               -16.4920
#             A Day In The Life - Remastered 2009                 -14.1620
# ...                                                                  ...
#             You Really Got A Hold On Me - Remastered 2009        -9.3100
#             You Won't See Me - Remastered 2009                   -8.7520
#             You're Going To Lose That Girl - Remastered 2009     -7.6940
#             You've Got To Hide Your Love Away - Remastered ...   -9.3255
#             Your Mother Should Know - Remastered 2009           -11.3610
#
#                                                                 mode  \
# artists     name
# The Beatles A Day In The Life                                    0.0
#             A Day In The Life - First Mono Mix                   0.0
#             A Day In The Life - Hummed Last Chord / Takes 8...   1.0
#             A Day In The Life - Orchestra Overdub                1.0
#             A Day In The Life - Remastered 2009                  0.0
# ...                                                              ...
#             You Really Got A Hold On Me - Remastered 2009        1.0
#             You Won't See Me - Remastered 2009                   1.0
#             You're Going To Lose That Girl - Remastered 2009     1.0
#             You've Got To Hide Your Love Away - Remastered ...   1.0
#             Your Mother Should Know - Remastered 2009            1.0
#
#                                                                 popularity  \
# artists     name
# The Beatles A Day In The Life                                         28.0
#             A Day In The Life - First Mono Mix                        24.0
#             A Day In The Life - Hummed Last Chord / Takes 8...        24.0
#             A Day In The Life - Orchestra Overdub                     24.0
#             A Day In The Life - Remastered 2009                       66.0
# ...                                                                    ...
#             You Really Got A Hold On Me - Remastered 2009             58.0
#             You Won't See Me - Remastered 2009                        59.0
#             You're Going To Lose That Girl - Remastered 2009          59.0
#             You've Got To Hide Your Love Away - Remastered ...        51.5
#             Your Mother Should Know - Remastered 2009                 54.0
#
#                                                                 speechiness  \
# artists     name
# The Beatles A Day In The Life                                        0.0474
#             A Day In The Life - First Mono Mix                       0.0467
#             A Day In The Life - Hummed Last Chord / Takes 8...       0.5160
#             A Day In The Life - Orchestra Overdub                    0.0420
#             A Day In The Life - Remastered 2009                      0.0675
# ...                                                                     ...
#             You Really Got A Hold On Me - Remastered 2009            0.0337
#             You Won't See Me - Remastered 2009                       0.0304
#             You're Going To Lose That Girl - Remastered 2009         0.0337
#             You've Got To Hide Your Love Away - Remastered ...       0.0287
#             Your Mother Should Know - Remastered 2009                0.0332
#
#                                                                    tempo  \
# artists     name
# The Beatles A Day In The Life                                    78.7420
#             A Day In The Life - First Mono Mix                   80.5890
#             A Day In The Life - Hummed Last Chord / Takes 8...  152.3290
#             A Day In The Life - Orchestra Overdub                83.1050
#             A Day In The Life - Remastered 2009                 163.2190
# ...                                                                  ...
#             You Really Got A Hold On Me - Remastered 2009        77.6430
#             You Won't See Me - Remastered 2009                  115.9410
#             You're Going To Lose That Girl - Remastered 2009    131.9750
#             You've Got To Hide Your Love Away - Remastered ...  184.2805
#             Your Mother Should Know - Remastered 2009           117.6130
#
#                                                                 valence  \
# artists     name
# The Beatles A Day In The Life                                    0.1490
#             A Day In The Life - First Mono Mix                   0.2410
#             A Day In The Life - Hummed Last Chord / Takes 8...   0.3250
#             A Day In The Life - Orchestra Overdub                0.1840
#             A Day In The Life - Remastered 2009                  0.1750
# ...                                                                 ...
#             You Really Got A Hold On Me - Remastered 2009        0.6870
#             You Won't See Me - Remastered 2009                   0.4730
#             You're Going To Lose That Girl - Remastered 2009     0.8180
#             You've Got To Hide Your Love Away - Remastered ...   0.3825
#             Your Mother Should Know - Remastered 2009            0.7240
#
#                                                                   year
# artists     name
# The Beatles A Day In The Life                                   1967.0
#             A Day In The Life - First Mono Mix                  1967.0
#             A Day In The Life - Hummed Last Chord / Takes 8...  1967.0
#             A Day In The Life - Orchestra Overdub               1967.0
#             A Day In The Life - Remastered 2009                 1967.0
# ...                                                                ...
#             You Really Got A Hold On Me - Remastered 2009       1963.0
#             You Won't See Me - Remastered 2009                  1965.0
#             You're Going To Lose That Girl - Remastered 2009    1965.0
#             You've Got To Hide Your Love Away - Remastered ...  1969.0
#             Your Mother Should Know - Remastered 2009           1967.0
#
# [329 rows x 15 columns]

# %%
beatles['this song']=beatles['name'].apply(lambda x : 1 if 'a day in the life' in x.lower() else 0)

# %%
pd.pivot_table(beatles, index= ['this song'], aggfunc = 'count')#), values = 'name')#.sort_values('average_salary' , ascending = False)
# Out:
#            acousticness  artists  danceability  duration_ms  energy  explicit  \
# this song
# 0                   395      395           395          395     395       395
# 1                    12       12            12           12      12        12
#
#             id  instrumentalness  key  liveness  loudness  mode  name  \
# this song
# 0          395               395  395       395       395   395   395
# 1           12                12   12        12        12    12    12
#
#            popularity  release_date  speechiness  tempo  valence  year
# this song
# 0                 395           395          395    395      395   395
# 1                  12            12           12     12       12    12

# %% [markdown]
# 1. There are many songs that have newer vesions like the remastereed versions.
#    So popularity of these songs is very difficult to assess
# 2. The popularity of the song itself is a very difficult thing to asses as the popularity depends
#    on the number of times it is played in the recent past by users.
#    This might help the spotify recommend songs but does not help us determing how the audiance perseives the song
#    or the absolute popularity of the song

# %% [markdown]
# ## Trying to figure our which tracks are the most popular

# %%
#but the problem is that we can't differentiate between the various releases and remastered versions 

#Most Popular Tracks
fig, axis = plt.subplots(figsize = (16,7))
popular = df.groupby("name")['popularity'].mean().sort_values(ascending=False).head(15)
axis = sns.barplot(popular, popular.index,palette="mako",orient = 'h')
axis.set_title('Top 15 Popular Tracks')
axis.set_ylabel('Tracks')
axis.set_xlabel('Popularity')
plt.xticks(rotation = 90)
# Out:
# (array([  0.,  20.,  40.,  60.,  80., 100., 120.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# Form this we can again see that the most popular songs are the ones that were
# released in the resent past and people tend to listen to them more often

# %%
#Most Popular Artists
fig, axis = plt.subplots(figsize = (16,7))
popular = df.groupby("artists")['popularity'].sum().sort_values(ascending=False)[:20]
axis = sns.barplot(popular,popular.index,palette="mako",orient = 'h')
axis.set_title('Top 20 Artists with Popularity')
axis.set_ylabel('Popularity')
axis.set_xlabel('Tracks')
plt.xticks(rotation = 90)
# Out:
# (array([    0.,  2500.,  5000.,  7500., 10000., 12500., 15000., 17500.,
#         20000., 22500.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
# visualize the popularity of The Beatles songs over the year
Beatles = df[df['artists'] == 'The Beatles']
plt.rcParams['figure.figsize'] = (11,7)
# line plot passing x,y
sns.lineplot(x='year', y='popularity', data=Beatles, color='green')
# Labels
plt.title("The Beatles Popularity")
plt.xlabel('Year')
plt.ylabel('Popularity')
plt.show()

# %%
#Most Popular Artists
fig, axis = plt.subplots(figsize = (16,7))
popular = df.groupby("artists")['popularity'].mean().sort_values(ascending=False)[:20]
axis = sns.barplot(popular,popular.index,palette="mako",orient = 'h')
axis.set_title('Top 20 Artists with Popularity')
axis.set_ylabel('Popularity')
axis.set_xlabel('Tracks')
plt.xticks(rotation = 90)
# Out:
# (array([  0.,  20.,  40.,  60.,  80., 100., 120.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
# visualize the popularity of Bad bunny songs over the year
Bad_bunny = df[df['artists'] == 'Bad Bunny, Jhay Cortez']
plt.rcParams['figure.figsize'] = (11,7)
# line plot passing x,y
sns.scatterplot(x='year', y='popularity', data=Bad_bunny, color='green')
# Labels
plt.title("Bad Bunny and Jhay Cortez Popularity")
plt.xlabel('Year')
plt.ylabel('Popularity')
plt.show()

# %%
df[df['artists']=='Bad Bunny, Jhay Cortez']
# Out:
#        valence  year  acousticness                 artists  danceability  \
# 19611    0.145  2020         0.401  Bad Bunny, Jhay Cortez         0.731
#
#        duration_ms  energy  explicit                      id  \
# 19611       205090   0.573         1  47EiUVwUp4C9fGccaPuUCS
#
#        instrumentalness  key  liveness  loudness  mode    name  popularity  \
# 19611          0.000052    4     0.113   -10.059     0  Dakiti         100
#
#       release_date  speechiness    tempo
# 19611   2020-10-30       0.0544  109.928

# %%
Beatles.sort_values(['release_date'], ascending = False )
# Out:
#         valence  year  acousticness      artists  danceability  duration_ms  \
# 107536    0.654  2014         0.208  The Beatles         0.616       159160
# 91100     0.621  2014         0.836  The Beatles         0.521       125227
# 152882    0.216  2006         0.676  The Beatles         0.417       226757
# 138138    0.195  2006         0.828  The Beatles         0.483       151992
# 35840     0.585  2006         0.091  The Beatles         0.462       238854
# ...         ...   ...           ...          ...           ...          ...
# 8357      0.929  1963         0.608  The Beatles         0.654       145080
# 8308      0.770  1963         0.389  The Beatles         0.635       124360
# 8327      0.597  1963         0.767  The Beatles         0.605       146533
# 8331      0.822  1963         0.607  The Beatles         0.402       146440
# 8210      0.937  1963         0.641  The Beatles         0.482       155227
#
#         energy  explicit                      id  instrumentalness  key  \
# 107536   0.636         0  1tdltVUBkiBCW1C3yB4zyD          0.000000    1
# 91100    0.301         0  6EOKwO6WaLal58MSsi6U4W          0.000000    4
# 152882   0.163         0  0FzGKD3N0jK6nNOyOJBvNG          0.000211    5
# 138138   0.107         0  41ETKVJbZDSjATzW2wAqmc          0.000000    5
# 35840    0.632         0  1eT2CjXwFXNx6oY5ydvzKU          0.000000    5
# ...        ...       ...                     ...               ...  ...
# 8357     0.561         0  3JQWLa88R35d971o5bIImd          0.000000   10
# 8308     0.656         0  7Msq9qojB7yORuJvz49iUy          0.001270    2
# 8327     0.394         0  7529Z6b1rlGZFFPWjHPeV5          0.000000    4
# 8331     0.860         0  7JxGM1R32ZqfwZou3VtnTg          0.000000    4
# 8210     0.849         0  5ZBeML7Lf3FMEVviTyvi8l          0.000008    2
#
#         liveness  loudness  mode                               name  \
# 107536    0.5170    -7.055     1                   Yellow Submarine
# 91100     0.3980    -7.118     0                      Eleanor Rigby
# 152882    0.1120   -14.445     1       While My Guitar Gently Weeps
# 138138    0.0920   -15.465     1              Blackbird / Yesterday
# 35840     0.3970    -7.438     1                           Hey Jude
# ...          ...       ...   ...                                ...
# 8357      0.1290   -10.551     1           Chains - Remastered 2009
# 8308      0.0828    -8.500     1  P.S. I Love You - Remastered 2009
# 8327      0.0967   -11.330     1       Ask Me Why - Remastered 2009
# 8331      0.7360   -10.310     1             Boys - Remastered 2009
# 8210      0.0414    -9.198     1  Twist And Shout - Remastered 2009
#
#         popularity release_date  speechiness    tempo
# 107536          59   2014-01-01       0.0325  110.618
# 91100           57   2014-01-01       0.0356  137.382
# 152882          49   2006-11-17       0.0369  122.610
# 138138          47   2006-11-17       0.0310   94.371
# 35840           62   2006-11-17       0.0248   74.268
# ...            ...          ...          ...      ...
# 8357            47   1963-03-22       0.0304  129.884
# 8308            50   1963-03-22       0.0291  134.435
# 8327            49   1963-03-22       0.0378  133.942
# 8331            49   1963-03-22       0.0504  142.445
# 8210            74   1963-03-22       0.0452  124.631
#
# [407 rows x 19 columns]

# %% [markdown]
# We see that the beetles are the most popular band at the current moment if you sum up their popularity.
# If we take the mean popularity we see it is by Bad Bunny.
# This shows that the beetles have a very stong fan following but the overall populatiry is still dominated by how recent the song was released.
# Any more study on popularty will be futile

# %%
columns = ["acousticness","danceability","energy","speechiness","liveness","valence"]
plt.figure(figsize=(20,10))
for c in columns:
    x = df.groupby('year')[c].mean()
    sns.lineplot(x.index,x,label=c)
plt.title('Audio characteristics over the years', fontsize=40)
plt.xlabel('Year',fontsize=30)
plt.ylabel('Characteristics',fontsize=22)
plt.legend(fancybox=True, framealpha=1, shadow=True, borderpad=1, prop={'size': 20}, loc = 'upper right')
plt.show()

# %% [markdown]
# # Trial section

# %%
k = pd.DataFrame(x)#, columns=['year','hjgv'])

# %%
k.columns=['year','dsf']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-8b379f848142> in <module>
# ----> 1 k.columns=['year','dsf']
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5150         try:
#    5151             object.__getattribute__(self, name)
# -> 5152             return object.__setattr__(self, name, value)
#    5153         except AttributeError:
#    5154             pass
#
# pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     562     def _set_axis(self, axis: int, labels: Index) -> None:
#     563         labels = ensure_index(labels)
# --> 564         self._mgr.set_axis(axis, labels)
#     565         self._clear_item_cache()
#     566
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in set_axis(self, axis, new_labels)
#     224
#     225         if new_len != old_len:
# --> 226             raise ValueError(
#     227                 f"Length mismatch: Expected axis has {old_len} elements, new "
#     228                 f"values have {new_len} elements"
#
# ValueError: Length mismatch: Expected axis has 1 elements, new values have 2 elements

# %%
a = x.tolist()
b = x.index.tolist()
a.append(b)

# %%
len(a)

# %%
columns = ['acousticness','danceability', 'duration_ms', 'energy', 'explicit',
       'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
       'popularity', 'speechiness', 'tempo', 'valence']
for col in columns:
    x = df.groupby('year')[col].mean()
    sns.lineplot(x.index,x,label=col)
    plt.figure(figsize=(15, 5))
    sns.set_style("whitegrid")
    #sns.lineplot(x, y, data=df)

# %%
y = df.groupby('year')[col].mean()

# %%
#sns.pairplot(df , vars = ['year', 'acousticness', 'artists', 'danceability',
#       'energy', 'liveness', 'loudness', 'mode', 'name', 'popularity', 'release_date',
#       'speechiness'])

# %%
import plotly.express as px 

top10_genres = df_gener.nlargest(10, 'popularity')

fig = px.bar(top10_genres, x='genres', y=['acousticness', 'danceability',
       'energy', 'instrumentalness', 'liveness', 'speechiness',
       'valence'], barmode='group')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-0c0fe3e1119d> in <module>
#       3 top10_genres = df_gener.nlargest(10, 'popularity')
#       4
# ----> 5 fig = px.bar(top10_genres, x='genres', y=['acousticness', 'danceability',
#       6        'energy', 'instrumentalness', 'liveness', 'speechiness',
#       7        'valence'], barmode='group')
#
# ~\anaconda3\lib\site-packages\plotly\express\_chart_types.py in bar(data_frame, x, y, color, pattern_shape, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, hover_name, hover_data, custom_data, text, base, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, color_continuous_scale, pattern_shape_sequence, pattern_shape_map, range_color, color_continuous_midpoint, opacity, orientation, barmode, log_x, log_y, range_x, range_y, title, template, width, height)
#     351     mark.
#     352     """
# --> 353     return make_figure(
#     354         args=locals(),
#     355         constructor=go.Bar,
#
# ~\anaconda3\lib\site-packages\plotly\express\_core.py in make_figure(args, constructor, trace_patch, layout_patch)
#    2119     fig.update_layout(layout_patch)
#    2120     if "template" in args and args["template"] is not None:
# -> 2121         fig.update_layout(template=args["template"], overwrite=True)
#    2122     fig.frames = frame_list if len(frames) > 1 else []
#    2123
#
# ~\anaconda3\lib\site-packages\plotly\basedatatypes.py in update_layout(self, dict1, overwrite, **kwargs)
#    1401             The Figure object that the update_layout method was called on
#    1402         """
# -> 1403         self.layout.update(dict1, overwrite=overwrite, **kwargs)
#    1404         return self
#    1405
#
# ~\anaconda3\lib\site-packages\plotly\basedatatypes.py in update(self, dict1, overwrite, **kwargs)
#    5080             with self.figure.batch_update():
#    5081                 BaseFigure._perform_update(self, dict1, overwrite=overwrite)
# -> 5082                 BaseFigure._perform_update(self, kwargs, overwrite=overwrite)
#    5083         else:
#    5084             BaseFigure._perform_update(self, dict1, overwrite=overwrite)
#
# ~\anaconda3\lib\site-packages\plotly\basedatatypes.py in _perform_update(plotly_obj, update_obj, overwrite)
#    3889                 if overwrite:
#    3890                     # Don't recurse and assign property as-is
# -> 3891                     plotly_obj[key] = val
#    3892                     continue
#    3893
#
# ~\anaconda3\lib\site-packages\plotly\basedatatypes.py in __setitem__(self, prop, value)
#    5819         if match is None:
#    5820             # Set as ordinary property
# -> 5821             super(BaseLayoutHierarchyType, self).__setitem__(prop, value)
#    5822         else:
#    5823             # Set as subplotid property
#
# ~\anaconda3\lib\site-packages\plotly\basedatatypes.py in __setitem__(self, prop, value)
#    4809                 # ### Handle compound property ###
#    4810                 if isinstance(validator, CompoundValidator):
# -> 4811                     self._set_compound_prop(prop, value)
#    4812
#    4813                 # ### Handle compound array property ###
#
# ~\anaconda3\lib\site-packages\plotly\basedatatypes.py in _set_compound_prop(self, prop, val)
#    5220         # ------------
#    5221         validator = self._get_validator(prop)
# -> 5222         val = validator.validate_coerce(val, skip_invalid=self._skip_invalid)
#    5223
#    5224         # Save deep copies of current and new states
#
# ~\anaconda3\lib\site-packages\_plotly_utils\basevalidators.py in validate_coerce(self, v, skip_invalid)
#    2745             return self.data_class(data_scatter=[{}])
#    2746
# -> 2747         return super(BaseTemplateValidator, self).validate_coerce(
#    2748             v, skip_invalid=skip_invalid
#    2749         )
#
# ~\anaconda3\lib\site-packages\_plotly_utils\basevalidators.py in validate_coerce(self, v, skip_invalid, _validate)
#    2456         elif isinstance(v, self.data_class):
#    2457             # Copy object
# -> 2458             v = self.data_class(v)
#    2459         else:
#    2460             if skip_invalid:
#
# ~\anaconda3\lib\site-packages\plotly\graph_objs\layout\_template.py in __init__(self, arg, data, layout, **kwargs)
#     317         _v = data if data is not None else _v
#     318         if _v is not None:
# --> 319             self["data"] = _v
#     320         _v = arg.pop("layout", None)
#     321         _v = layout if layout is not None else _v
#
# ~\anaconda3\lib\site-packages\plotly\basedatatypes.py in __setitem__(self, prop, value)
#    4809                 # ### Handle compound property ###
#    4810                 if isinstance(validator, CompoundValidator):
# -> 4811                     self._set_compound_prop(prop, value)
#    4812
#    4813                 # ### Handle compound array property ###
#
# ~\anaconda3\lib\site-packages\plotly\basedatatypes.py in _set_compound_prop(self, prop, val)
#    5220         # ------------
#    5221         validator = self._get_validator(prop)
# -> 5222         val = validator.validate_coerce(val, skip_invalid=self._skip_invalid)
#    5223
#    5224         # Save deep copies of current and new states
#
# ~\anaconda3\lib\site-packages\_plotly_utils\basevalidators.py in validate_coerce(self, v, skip_invalid, _validate)
#    2452
#    2453         elif isinstance(v, dict):
# -> 2454             v = self.data_class(v, skip_invalid=skip_invalid, _validate=_validate)
#    2455
#    2456         elif isinstance(v, self.data_class):
#
# ~\anaconda3\lib\site-packages\plotly\graph_objs\layout\template\_data.py in __init__(self, arg, barpolar, bar, box, candlestick, carpet, choroplethmapbox, choropleth, cone, contourcarpet, contour, densitymapbox, funnelarea, funnel, heatmapgl, heatmap, histogram2dcontour, histogram2d, histogram, icicle, image, indicator, isosurface, mesh3d, ohlc, parcats, parcoords, pie, pointcloud, sankey, scatter3d, scattercarpet, scattergeo, scattergl, scattermapbox, scatterpolargl, scatterpolar, scatter, scatterternary, splom, streamtube, sunburst, surface, table, treemap, violin, volume, waterfall, **kwargs)
#    1531         _v = barpolar if barpolar is not None else _v
#    1532         if _v is not None:
# -> 1533             self["barpolar"] = _v
#    1534         _v = arg.pop("bar", None)
#    1535         _v = bar if bar is not None else _v
#
# ~\anaconda3\lib\site-packages\plotly\basedatatypes.py in __setitem__(self, prop, value)
#    4813                 # ### Handle compound array property ###
#    4814                 elif isinstance(validator, (CompoundArrayValidator, BaseDataValidator)):
# -> 4815                     self._set_array_prop(prop, value)
#    4816
#    4817                 # ### Handle simple property ###
#
# ~\anaconda3\lib\site-packages\plotly\basedatatypes.py in _set_array_prop(self, prop, val)
#    5294         # ------------
#    5295         validator = self._get_validator(prop)
# -> 5296         val = validator.validate_coerce(val, skip_invalid=self._skip_invalid)
#    5297
#    5298         # Save deep copies of current and new states
#
# ~\anaconda3\lib\site-packages\_plotly_utils\basevalidators.py in validate_coerce(self, v, skip_invalid)
#    2544                     res.append(self.data_class(v_el))
#    2545                 elif isinstance(v_el, dict):
# -> 2546                     res.append(self.data_class(v_el, skip_invalid=skip_invalid))
#    2547                 else:
#    2548                     if skip_invalid:
#
# ~\anaconda3\lib\site-packages\plotly\graph_objs\_barpolar.py in __init__(self, arg, base, basesrc, customdata, customdatasrc, dr, dtheta, hoverinfo, hoverinfosrc, hoverlabel, hovertemplate, hovertemplatesrc, hovertext, hovertextsrc, ids, idssrc, legendgroup, legendgrouptitle, legendrank, marker, meta, metasrc, name, offset, offsetsrc, opacity, r, r0, rsrc, selected, selectedpoints, showlegend, stream, subplot, text, textsrc, theta, theta0, thetasrc, thetaunit, uid, uirevision, unselected, visible, width, widthsrc, **kwargs)
#    1838         _v = marker if marker is not None else _v
#    1839         if _v is not None:
# -> 1840             self["marker"] = _v
#    1841         _v = arg.pop("meta", None)
#    1842         _v = meta if meta is not None else _v
#
# ~\anaconda3\lib\site-packages\plotly\basedatatypes.py in __setitem__(self, prop, value)
#    4809                 # ### Handle compound property ###
#    4810                 if isinstance(validator, CompoundValidator):
# -> 4811                     self._set_compound_prop(prop, value)
#    4812
#    4813                 # ### Handle compound array property ###
#
# ~\anaconda3\lib\site-packages\plotly\basedatatypes.py in _set_compound_prop(self, prop, val)
#    5220         # ------------
#    5221         validator = self._get_validator(prop)
# -> 5222         val = validator.validate_coerce(val, skip_invalid=self._skip_invalid)
#    5223
#    5224         # Save deep copies of current and new states
#
# ~\anaconda3\lib\site-packages\_plotly_utils\basevalidators.py in validate_coerce(self, v, skip_invalid, _validate)
#    2452
#    2453         elif isinstance(v, dict):
# -> 2454             v = self.data_class(v, skip_invalid=skip_invalid, _validate=_validate)
#    2455
#    2456         elif isinstance(v, self.data_class):
#
# ~\anaconda3\lib\site-packages\plotly\graph_objs\barpolar\_marker.py in __init__(self, arg, autocolorscale, cauto, cmax, cmid, cmin, color, coloraxis, colorbar, colorscale, colorsrc, line, opacity, opacitysrc, pattern, reversescale, showscale, **kwargs)
#    1133         _v = pattern if pattern is not None else _v
#    1134         if _v is not None:
# -> 1135             self["pattern"] = _v
#    1136         _v = arg.pop("reversescale", None)
#    1137         _v = reversescale if reversescale is not None else _v
#
# ~\anaconda3\lib\site-packages\plotly\basedatatypes.py in __setitem__(self, prop, value)
#    4809                 # ### Handle compound property ###
#    4810                 if isinstance(validator, CompoundValidator):
# -> 4811                     self._set_compound_prop(prop, value)
#    4812
#    4813                 # ### Handle compound array property ###
#
# ~\anaconda3\lib\site-packages\plotly\basedatatypes.py in _set_compound_prop(self, prop, val)
#    5220         # ------------
#    5221         validator = self._get_validator(prop)
# -> 5222         val = validator.validate_coerce(val, skip_invalid=self._skip_invalid)
#    5223
#    5224         # Save deep copies of current and new states
#
# ~\anaconda3\lib\site-packages\_plotly_utils\basevalidators.py in validate_coerce(self, v, skip_invalid, _validate)
#    2452
#    2453         elif isinstance(v, dict):
# -> 2454             v = self.data_class(v, skip_invalid=skip_invalid, _validate=_validate)
#    2455
#    2456         elif isinstance(v, self.data_class):
#
# ~\anaconda3\lib\site-packages\plotly\graph_objs\barpolar\marker\_pattern.py in __init__(self, arg, bgcolor, bgcolorsrc, fgcolor, fgcolorsrc, fgopacity, fillmode, shape, shapesrc, size, sizesrc, solidity, soliditysrc, **kwargs)
#     546         _v = fillmode if fillmode is not None else _v
#     547         if _v is not None:
# --> 548             self["fillmode"] = _v
#     549         _v = arg.pop("shape", None)
#     550         _v = shape if shape is not None else _v
#
# ~\anaconda3\lib\site-packages\plotly\basedatatypes.py in __setitem__(self, prop, value)
#    4805
#    4806                 # ### Get validator for this property ###
# -> 4807                 validator = self._get_validator(prop)
#    4808
#    4809                 # ### Handle compound property ###
#
# ~\anaconda3\lib\site-packages\plotly\basedatatypes.py in _get_validator(self, prop)
#    4287         from .validator_cache import ValidatorCache
#    4288
# -> 4289         return ValidatorCache.get_validator(self._path_str, prop)
#    4290
#    4291     @property
#
# ~\anaconda3\lib\site-packages\plotly\validator_cache.py in get_validator(parent_path, prop_name)
#      27                 class_name = lookup_name.title() + "Validator"
#      28                 validator = getattr(
# ---> 29                     importlib.import_module("plotly.validators." + parent_path),
#      30                     class_name,
#      31                 )(plotly_name=prop_name)
#
# ~\anaconda3\lib\importlib\__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# ~\anaconda3\lib\importlib\_bootstrap.py in _gcd_import(name, package, level)
#
# ~\anaconda3\lib\importlib\_bootstrap.py in _find_and_load(name, import_)
#
# ~\anaconda3\lib\importlib\_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ~\anaconda3\lib\importlib\_bootstrap.py in _load_unlocked(spec)
#
# ~\anaconda3\lib\importlib\_bootstrap_external.py in exec_module(self, module)
#
# ~\anaconda3\lib\importlib\_bootstrap_external.py in get_code(self, fullname)
#
# ~\anaconda3\lib\importlib\_bootstrap_external.py in get_data(self, path)
#
# KeyboardInterrupt:

# %% [markdown]
# We can see from this graph that some of the the top gener songs have
# 1. High Energy
# 2. High Danceability
# 3. Valence
# 4. low speechiness, liveliness , instrumentalness

# %%
import plotly.express as px 

top10_genres = df_gener.nlargest(10, 'popularity')

fig = px.bar(top10_genres, x='genres', y=['duration_ms'], barmode='group')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-43-316ad6e49b9d> in <module>
#       3 top10_genres = df_gener.nlargest(10, 'popularity')
#       4
# ----> 5 fig = px.bar(top10_genres, x='genres', y=['duration_ms'], barmode='group')
#       6 fig.show()
#
# ~\anaconda3\lib\site-packages\plotly\express\_chart_types.py in bar(data_frame, x, y, color, pattern_shape, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, hover_name, hover_data, custom_data, text, base, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, color_continuous_scale, pattern_shape_sequence, pattern_shape_map, range_color, color_continuous_midpoint, opacity, orientation, barmode, log_x, log_y, range_x, range_y, title, template, width, height)
#     351     mark.
#     352     """
# --> 353     return make_figure(
#     354         args=locals(),
#     355         constructor=go.Bar,
#
# ~\anaconda3\lib\site-packages\plotly\express\_core.py in make_figure(args, constructor, trace_patch, layout_patch)
#    2119     fig.update_layout(layout_patch)
#    2120     if "template" in args and args["template"] is not None:
# -> 2121         fig.update_layout(template=args["template"], overwrite=True)
#    2122     fig.frames = frame_list if len(frames) > 1 else []
#    2123
#
# ~\anaconda3\lib\site-packages\plotly\basedatatypes.py in update_layout(self, dict1, overwrite, **kwargs)
#    1401             The Figure object that the update_layout method was called on
#    1402         """
# -> 1403         self.layout.update(dict1, overwrite=overwrite, **kwargs)
#    1404         return self
#    1405
#
# ~\anaconda3\lib\site-packages\plotly\basedatatypes.py in update(self, dict1, overwrite, **kwargs)
#    5080             with self.figure.batch_update():
#    5081                 BaseFigure._perform_update(self, dict1, overwrite=overwrite)
# -> 5082                 BaseFigure._perform_update(self, kwargs, overwrite=overwrite)
#    5083         else:
#    5084             BaseFigure._perform_update(self, dict1, overwrite=overwrite)
#
# ~\anaconda3\lib\site-packages\plotly\basedatatypes.py in _perform_update(plotly_obj, update_obj, overwrite)
#    3889                 if overwrite:
#    3890                     # Don't recurse and assign property as-is
# -> 3891                     plotly_obj[key] = val
#    3892                     continue
#    3893
#
# ~\anaconda3\lib\site-packages\plotly\basedatatypes.py in __setitem__(self, prop, value)
#    5819         if match is None:
#    5820             # Set as ordinary property
# -> 5821             super(BaseLayoutHierarchyType, self).__setitem__(prop, value)
#    5822         else:
#    5823             # Set as subplotid property
#
# ~\anaconda3\lib\site-packages\plotly\basedatatypes.py in __setitem__(self, prop, value)
#    4809                 # ### Handle compound property ###
#    4810                 if isinstance(validator, CompoundValidator):
# -> 4811                     self._set_compound_prop(prop, value)
#    4812
#    4813                 # ### Handle compound array property ###
#
# ~\anaconda3\lib\site-packages\plotly\basedatatypes.py in _set_compound_prop(self, prop, val)
#    5220         # ------------
#    5221         validator = self._get_validator(prop)
# -> 5222         val = validator.validate_coerce(val, skip_invalid=self._skip_invalid)
#    5223
#    5224         # Save deep copies of current and new states
#
# ~\anaconda3\lib\site-packages\_plotly_utils\basevalidators.py in validate_coerce(self, v, skip_invalid)
#    2745             return self.data_class(data_scatter=[{}])
#    2746
# -> 2747         return super(BaseTemplateValidator, self).validate_coerce(
#    2748             v, skip_invalid=skip_invalid
#    2749         )
#
# ~\anaconda3\lib\site-packages\_plotly_utils\basevalidators.py in validate_coerce(self, v, skip_invalid, _validate)
#    2456         elif isinstance(v, self.data_class):
#    2457             # Copy object
# -> 2458             v = self.data_class(v)
#    2459         else:
#    2460             if skip_invalid:
#
# ~\anaconda3\lib\site-packages\plotly\graph_objs\layout\_template.py in __init__(self, arg, data, layout, **kwargs)
#     321         _v = layout if layout is not None else _v
#     322         if _v is not None:
# --> 323             self["layout"] = _v
#     324
#     325         # Process unknown kwargs
#
# ~\anaconda3\lib\site-packages\plotly\basedatatypes.py in __setitem__(self, prop, value)
#    4809                 # ### Handle compound property ###
#    4810                 if isinstance(validator, CompoundValidator):
# -> 4811                     self._set_compound_prop(prop, value)
#    4812
#    4813                 # ### Handle compound array property ###
#
# ~\anaconda3\lib\site-packages\plotly\basedatatypes.py in _set_compound_prop(self, prop, val)
#    5220         # ------------
#    5221         validator = self._get_validator(prop)
# -> 5222         val = validator.validate_coerce(val, skip_invalid=self._skip_invalid)
#    5223
#    5224         # Save deep copies of current and new states
#
# ~\anaconda3\lib\site-packages\_plotly_utils\basevalidators.py in validate_coerce(self, v, skip_invalid, _validate)
#    2452
#    2453         elif isinstance(v, dict):
# -> 2454             v = self.data_class(v, skip_invalid=skip_invalid, _validate=_validate)
#    2455
#    2456         elif isinstance(v, self.data_class):
#
# ~\anaconda3\lib\site-packages\plotly\graph_objs\_layout.py in __init__(self, arg, activeshape, annotations, annotationdefaults, autosize, autotypenumbers, bargap, bargroupgap, barmode, barnorm, boxgap, boxgroupgap, boxmode, calendar, clickmode, coloraxis, colorscale, colorway, computed, datarevision, dragmode, editrevision, extendfunnelareacolors, extendiciclecolors, extendpiecolors, extendsunburstcolors, extendtreemapcolors, font, funnelareacolorway, funnelgap, funnelgroupgap, funnelmode, geo, grid, height, hiddenlabels, hiddenlabelssrc, hidesources, hoverdistance, hoverlabel, hovermode, iciclecolorway, images, imagedefaults, legend, mapbox, margin, meta, metasrc, modebar, newshape, paper_bgcolor, piecolorway, plot_bgcolor, polar, scene, selectdirection, selectionrevision, separators, shapes, shapedefaults, showlegend, sliders, sliderdefaults, spikedistance, sunburstcolorway, template, ternary, title, titlefont, transition, treemapcolorway, uirevision, uniformtext, updatemenus, updatemenudefaults, violingap, violingroupgap, violinmode, waterfallgap, waterfallgroupgap, waterfallmode, width, xaxis, yaxis, **kwargs)
#    6093         _v = polar if polar is not None else _v
#    6094         if _v is not None:
# -> 6095             self["polar"] = _v
#    6096         _v = arg.pop("scene", None)
#    6097         _v = scene if scene is not None else _v
#
# ~\anaconda3\lib\site-packages\plotly\basedatatypes.py in __setitem__(self, prop, value)
#    5819         if match is None:
#    5820             # Set as ordinary property
# -> 5821             super(BaseLayoutHierarchyType, self).__setitem__(prop, value)
#    5822         else:
#    5823             # Set as subplotid property
#
# ~\anaconda3\lib\site-packages\plotly\basedatatypes.py in __setitem__(self, prop, value)
#    4809                 # ### Handle compound property ###
#    4810                 if isinstance(validator, CompoundValidator):
# -> 4811                     self._set_compound_prop(prop, value)
#    4812
#    4813                 # ### Handle compound array property ###
#
# ~\anaconda3\lib\site-packages\plotly\basedatatypes.py in _set_compound_prop(self, prop, val)
#    5220         # ------------
#    5221         validator = self._get_validator(prop)
# -> 5222         val = validator.validate_coerce(val, skip_invalid=self._skip_invalid)
#    5223
#    5224         # Save deep copies of current and new states
#
# ~\anaconda3\lib\site-packages\_plotly_utils\basevalidators.py in validate_coerce(self, v, skip_invalid, _validate)
#    2452
#    2453         elif isinstance(v, dict):
# -> 2454             v = self.data_class(v, skip_invalid=skip_invalid, _validate=_validate)
#    2455
#    2456         elif isinstance(v, self.data_class):
#
# ~\anaconda3\lib\site-packages\plotly\graph_objs\layout\_polar.py in __init__(self, arg, angularaxis, bargap, barmode, bgcolor, domain, gridshape, hole, radialaxis, sector, uirevision, **kwargs)
#    1009         _v = angularaxis if angularaxis is not None else _v
#    1010         if _v is not None:
# -> 1011             self["angularaxis"] = _v
#    1012         _v = arg.pop("bargap", None)
#    1013         _v = bargap if bargap is not None else _v
#
# ~\anaconda3\lib\site-packages\plotly\basedatatypes.py in __setitem__(self, prop, value)
#    4805
#    4806                 # ### Get validator for this property ###
# -> 4807                 validator = self._get_validator(prop)
#    4808
#    4809                 # ### Handle compound property ###
#
# ~\anaconda3\lib\site-packages\plotly\basedatatypes.py in _get_validator(self, prop)
#    4287         from .validator_cache import ValidatorCache
#    4288
# -> 4289         return ValidatorCache.get_validator(self._path_str, prop)
#    4290
#    4291     @property
#
# ~\anaconda3\lib\site-packages\plotly\validator_cache.py in get_validator(parent_path, prop_name)
#      27                 class_name = lookup_name.title() + "Validator"
#      28                 validator = getattr(
# ---> 29                     importlib.import_module("plotly.validators." + parent_path),
#      30                     class_name,
#      31                 )(plotly_name=prop_name)
#
# ~\anaconda3\lib\importlib\__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# ~\anaconda3\lib\importlib\_bootstrap.py in _gcd_import(name, package, level)
#
# ~\anaconda3\lib\importlib\_bootstrap.py in _find_and_load(name, import_)
#
# ~\anaconda3\lib\importlib\_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ~\anaconda3\lib\importlib\_bootstrap.py in _load_unlocked(spec)
#
# ~\anaconda3\lib\importlib\_bootstrap_external.py in exec_module(self, module)
#
# ~\anaconda3\lib\importlib\_bootstrap_external.py in get_code(self, fullname)
#
# ~\anaconda3\lib\importlib\_bootstrap_external.py in get_data(self, path)
#
# KeyboardInterrupt:

# %% [markdown]
# # End of trial section

# %% [markdown]
# ## Feature Selection
# We need to design a ML Model that can predicts the Popularity based on the features available.
# In order to select the features for the model I am using YellowbrickFeature Correlation Visualizer.
#
# This visualizer calculates Pearson correlation coefficients and mutual information between
# features and the dependent variable. This visualization can be used in feature selection to identify features with high correlation or large mutual information with the dependent variable.

# %%
#from yellowbrick.target import FeatureCorrelation


feature_names = ['acousticness', 'danceability', 'energy', 'instrumentalness',
       'liveness', 'loudness', 'speechiness', 'tempo', 'valence','duration_ms','explicit','key','mode','year']

X, y = df[feature_names], df['popularity']

# Create a list of the feature names

features = np.array(feature_names)

# Instantiate the visualizer
visualizer = FeatureCorrelation(labels=features, font='22')

plt.rcParams['figure.figsize']=(30,30)
visualizer.fit(X, y)        # Fit the data to the visualizer
visualizer.show()
# Out:
# <AxesSubplot:title={'center':'Features correlation with dependent variable'}, xlabel='Pearson Correlation'>

# %% [markdown]
# # Pre Processing of Data and Finding best model

# %%
from sklearn.model_selection import train_test_split

# %%
cols = list(pd.read_csv('data_p.csv', nrows =1))
df1 = pd.read_csv('data_p.csv', usecols=[i for i in cols if i not in ['id','name','release_date']])

# Remove duplicated
df1 = df1.drop_duplicates()

#Split the data to train and test
X_train, X_test, y_train, y_test = train_test_split(df1.drop('popularity', axis=1), df1['popularity'], test_size = 0.2, random_state = 1)

# %% [markdown]
# id and name  are all feature that are unique for each entry and cannot give us any leverage for suggesting songs.
#
# Release_date columns is difficult handle as some of the songs only have the year while others have the day and month. So we will replace this column with year

# %%
from sklearn.preprocessing import FunctionTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler

# %%
class Artists:
    """
     This transformer recives a DF with a feature 'artists' of dtype object
      and convert the feature to a float value as follows:
      1. Replace the data with the artists mean popularity
      2. Replace values where artists appear less than MinCnt with y.mean()
      3. Replace values where artists appear more than MaxCnt with 0
      
      PARAMETERS:
      ----------
      MinCnt (int): Minimal treshold of artisits apear in dataset, default = 3
      MaxCnt (int): Maximal treshold of artisits apear in dataset, default = 600

      RERTURN:
      ----------
      A DataFrame with converted artists str feature to ordinal floats
    
    """
    def __init__(self, MinCnt = 3.0, MaxCnt = 600.0):
        self.MinCnt = MinCnt
        self.MaxCnt = MaxCnt
        self.artists_df = None

    def fit (self, X, y):
        self.artists_df =  y.groupby(X.artists).agg(['mean', 'count'])
        #print(self.artists_df.loc['unknown'])
        self.artists_df.loc['unknown'] = [y.mean(), 1]
        #print(self.artists_df.loc['unknown'])
        self.artists_df.loc[self.artists_df['count'] <= self.MinCnt, 'mean'] = y.mean()
        self.artists_df.loc[self.artists_df['count'] >= self.MaxCnt, 'mean'] = 0
        return self

    def transform(self, X, y=None):
        X['artists'] = np.where(X['artists'].isin(self.artists_df.index), X['artists'], 'unknown')
        X['artists'] = X['artists'].map(self.artists_df['mean'])
        return X
  
    
#Instrumental Transformer Criteria

def instrumental(X):
    X['instrumentalness'] = list(map((lambda x: 1 if x < 0.1 else (3 if x > 0.95 else 2)), X.instrumentalness))
    
    
class Tempo():
    """Eliminates Zero values from tempo columns and replace it 
       with the median or mean of non-zero values as specified.
       defaut is set to 'median'.
    """

    def __init__(self, method='median'):
        self.method = method

    def transform(self, X):
        if self.method == 'median':
            X.loc[X['tempo']==0, 'tempo'] = X.loc[X['tempo']>0, 'tempo'].median()
        elif self.method == 'mean':
            X.loc[X['tempo']==0, 'tempo'] = X.loc[X['tempo']>0, 'tempo'].mean()
        else:
            raise Exception("Method can be 'median' or 'mean' only!")
        return X

# %%
# Apply Aritists class on train and test seperatly
artists_transformer = Artists(MinCnt=2)
X_train = artists_transformer.fit(X_train, y_train).transform(X_train, y_train)
X_test = artists_transformer.transform(X_test, y_test)

#Apply Instrumental Criteria on train & test seperately
instrumentalness_tranformer = FunctionTransformer(instrumental)
instrumentalness_tranformer.transform(X_train)
instrumentalness_tranformer.transform(X_test)

#Apply Tempo Transformer class on Train & Test seperately
tempo_transformer = Tempo()
X_train = tempo_transformer.transform(X_train)
X_test = tempo_transformer.transform(X_test)

# %%
'''
plt.rcParams.update({'font.size': 22})


fig,ax = plt.subplots(1,1,figsize=(20,20))

sns.distplot(df['instrumentalness'])
'''
# Out:
# "\nplt.rcParams.update({'font.size': 22})\n\n\nfig,ax = plt.subplots(1,1,figsize=(20,20))\n\nsns.distplot(df['instrumentalness'])\n"

# %% [markdown]
# # Code below this is for ML Predicting the song popularity

# %%
import sklearn.metrics as metrics

def regression_result(y_true , y_pred):
    # regression metrics 
    explained_variance = metrics.explained_variance_score(y_true,y_pred)
    
    mean_aboslute_error = metrics.mean_absolute_error(y_true,y_pred)
    
    mse = metrics.mean_squared_log_error(y_true,y_pred)
    
    mean_squared_log_error = metrics.mean_squared_log_error(y_true,y_pred)
    
    r2 = metrics.r2_score(y_true,y_pred)
    
    
    # print statements 
    
    print('explained_variance:', round(explained_variance,4))
    print('mean_aboslute_error:', round(mean_aboslute_error,4))
    print('mse : ', round(mse ,4))
    print(' mean_squared_log_error : ', round( mean_squared_log_error,4))
    print('r2 :', round(r2,4))
    print('RMSE :', round(np.sqrt(mse) ,4))

# %%
from sklearn.model_selection import TimeSeriesSplit

from sklearn.linear_model import LinearRegression
from sklearn.neural_network import MLPRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # Code below this is for Recommendation System Implementation

# %%
df_copy = df 

def reset_df():
    return df_copy

# %%
def normalize_column(col):
    """
    col - column in the dataframe which needs to be normalized
    """
    max_d = df[col].max()
    min_d = df[col].min()
    df[col] = (df[col] - min_d)/(max_d - min_d)

# %%
#Normalize allnumerical columns so that min value is 0 and max value is 1
num_types = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
num = df.select_dtypes(include=num_types)
        
for col in num.columns:
    normalize_column(col)

# %%
#Progreebar
from tqdm import tqdm

# For transformations and predictions
from scipy.optimize import curve_fit
from yellowbrick.target import FeatureCorrelation
from sklearn.preprocessing import FunctionTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.cluster import KMeans 


# For scoring
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import r2_score,mean_absolute_error

# For validation
from sklearn.model_selection import train_test_split

# %%
'''
did kmeans for what I dont know 
inertias = []
for i in range(5,30):
    kmeans = KMeans(n_clusters=i)
    kmeans.fit(num)
    inertias.append(kmeans.inertia_)
'''
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-259-561de4638b6f> in <module>
#       5     inertias.append(kmeans.inertia_)
#       6
# ----> 7 plt.plot(range(1,11), inertias, marker='o')
#       8 plt.title('Elbow method')
#       9 plt.xlabel('Number of clusters')
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2838 @_copy_docstring_and_deprecators(Axes.plot)
#    2839 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
#    2842         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
#    1745             self.add_line(line)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in __call__(self, data, *args, **kwargs)
#     271                 this += args[0],
#     272                 args = args[1:]
# --> 273             yield from self._plot_args(this, kwargs)
#     274
#     275     def get_next_color(self):
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     397
#     398         if x.shape[0] != y.shape[0]:
# --> 399             raise ValueError(f"x and y must have same first dimension, but "
#     400                              f"have shapes {x.shape} and {y.shape}")
#     401         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (10,) and (25,)

# %%
'''
trying to plot the elbow plot for kmeas 
plt.plot(range(5,30), inertias, marker='o')
plt.title('Elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()
'''

# %%
'''
km = KMeans(n_clusters=7)
pred = km.fit_predict(num)
df['pred'] = pred
normalize_column('pred')
'''

# %%
class Song_Recommender():
    """
    Neighbourhood Based Collborative Filterng REcoomendation System using similarity Metrics
    Manhattan Distance is calculated for all songs and Recommend Songs that are similar to it based on any given song
    """
    def __init__(self, data):
        self.data_ = data
    
    #function which returns recommendations, we can also choose the amount of songs to be recommended
    def get_recommendations(self, song_name, n_top):
        distances = []
        #choosing the given song_name and dropping it from the data
        song = self.data_[(self.data_.name.str.lower() == song_name.lower())].head(1).values[0]
        rem_data = self.data_[self.data_.name.str.lower() != song_name.lower()]
        for r_song in tqdm(rem_data.values):
            dist = 0
            for col in np.arange(len(rem_data.columns)):
                #indeces of non-numerical columns(id,Release date,name,artists)
                if not col in [3,7,13]:
                    #calculating the manhettan distances for each numerical feature
                    dist = dist + np.absolute(float(song[col]) - float(r_song[col]))
            distances.append(dist)
        rem_data['distance'] = distances
        #sorting our data to be ascending by 'distance' feature
        rem_data = rem_data.sort_values('distance')
        columns = ['artists', 'name']
        return rem_data[columns][:n_top]

# %%
df.drop(['release_date','id'],axis=1,inplace=True)

# %%
#Instanstiate the Recommender Class
recommender = Song_Recommender(df)
recommender.get_recommendations('Red Roses (feat. Landon Cube)', 5)
# Out:
# 100%|██████████| 170652/170652 [00:06<00:00, 28227.99it/s]
#                                      artists  \
# 57027   ['Vince Staples', '6LACK', 'Mereba']
# 56966                ['Maroon 5', 'Cardi B']
# 104962                          ['S Club 7']
# 38093                              ['Bazzi']
# 74730             ['Lauv', 'Julia Michaels']
#
#                                                  name
# 57027   Yo Love - From "Queen & Slim: The Soundtrack"
# 56966                  Girls Like You (feat. Cardi B)
# 104962                                  Have You Ever
# 38093                                            3:15
# 74730           There's No Way (feat. Julia Michaels)

# %%
recommender.get_recommendations('canon in d', 10)
# Out:
# 100%|██████████| 170648/170648 [00:17<00:00, 9792.21it/s]
#                                                   artists  \
# 169454  Johann Pachelbel, Music Lab Collective, Valent...
# 105397                                      Thomas Newman
# 72203                                       Patrick Doyle
# 107547                                  Jóhann Jóhannsson
# 72737                                             Grouper
# 107287                                       Kevin Duncan
# 122483                                         David Tolk
# 71443                            Mulgrew Miller, Wingspan
# 50469                                     Ennio Morricone
# 105694            John Williams, Yo-Yo Ma, Itzhak Perlman
#
#                                       name
# 169454              Canon in D Major, P.37
# 105397                          Field Trip
# 72203                      Neville's Waltz
# 107547            The Theory of Everything
# 72737   Heavy Water/I'd Rather Be Sleeping
# 107287               Fairytale of New York
# 122483                               Grace
# 71443             It Never Entered My Mind
# 50469          On Earth As It Is In Heaven
# 105694                      Sayuri's Theme

# %%
df['pred'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'pred'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-62-b2ea71cefcca> in <module>
# ----> 1 df['pred'].value_counts()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'pred'

# %%
recommender.get_recommendations('dynamite', 10)
# Out:
# 100%|██████████| 170646/170646 [00:06<00:00, 27933.55it/s]
#                                                   artists  \
# 36728                                ['Bowling For Soup']
# 18017                                   ['One Direction']
# 17225                                       ['Lady Gaga']
# 54538                                    ['Billy Talent']
# 18085   ['Victorious Cast', 'Victoria Justice', 'Eliza...
# 18905                                      ['Little Mix']
# 107011                                      ['Glee Cast']
# 17818                                  ['Hot Chelle Rae']
# 91698                                        ['Paramore']
# 18192                                      ['Katy Perry']
#
#                                      name
# 36728                         Stacy's Mom
# 18017            What Makes You Beautiful
# 17225                          Poker Face
# 54538                       Fallen Leaves
# 18085                         Take A Hint
# 18905                  Shout Out to My Ex
# 107011  Loser Like Me (Glee Cast Version)
# 17818                     Tonight Tonight
# 91698                    Rose-Colored Boy
# 18192                          Part Of Me

# %%
import numpy as np 
random_numbers = np.random.randint(30,size = 6)
random_numbers.tolist()
# Out:
# [0, 20, 18, 18, 11, 28]

# %%
# 1d array to list
arr_1 = np.array([1, 2, 3])

print(f'NumPy Array:\n{arr_1}')

list_1 = arr_1.tolist()

print(f'List: {list_1}')
# Out:
# NumPy Array:
# [1 2 3]
# List: [1, 2, 3]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-3f73c4ac08b7> in <module>
# ----> 1 array('i', [45,34,67])
#
# NameError: name 'array' is not defined

# %%
import numpy as np
import os
import pandas as pd
from datetime import datetime

f = open("raw.txt", "rb")
#f.seek(1863, os.SEEK_SET)

data = np.fromfile(f, dtype=np.uint32)
df = pd.DataFrame(data)
#print(df)
np.savetxt('np.txt', df.values, fmt='%d')

# %%
import numpy as np
import os
import pandas as pd
from datetime import datetime

f = open("raw_kabap.txt", "rb")

data = np.fromfile(f)#, dtype=np.uint32)
df = pd.DataFrame(data)
#print(df)
np.savetxt('np1.txt', df.values, fmt='%d')

# %%
df_artists
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-75-d5fd5e81419e> in <module>
# ----> 1 df_artists
#
# NameError: name 'df_artists' is not defined

# %%
song_list = df['name'].unique()

# %%
np.random.randn(1, 1)
# Out:
# array([[-2.24423505]])

# %%
import pyarrow.feather as feather

# %%
song_list = df['name'].unique()

# %%
sdfsdf= pd.DataFrame(song_list, columns=['columns'])

# %%
sdfsdf.to_feather("song_list_df_feather.feather")

# %%
sdfsdf
# Out:
#                                                   columns
# 0       Piano Concerto No. 3 in D Minor, Op. 30: III. ...
# 1                                 Clancy Lowered the Boom
# 2                                               Gati Bali
# 3                                               Danny Boy
# 4                             When Irish Eyes Are Smiling
# ...                                                   ...
# 133633                             NASTY GIRL / ON CAMERA
# 133634                                    Med slutna ögon
# 133635                        Halloweenie III: Seven Days
# 133636                                                AYA
# 133637                    Billetes Azules (with J Balvin)
#
# [133638 rows x 1 columns]

# %%
df = pd.DataFrame(some_list, columns=["colummn"])
